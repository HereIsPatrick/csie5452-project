# %% [markdown]
# ## Traffic Sign Recognition(Spatial Transformer Network)

# %% [markdown]
# ### Data process

# %%
import warnings
warnings.filterwarnings('ignore') 
import pickle
from conv_model import conv_model
import numpy as np

from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam

training_file = './input/train.p'
testing_file = './input/test.p'
validating_file = './input/valid.p'

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
with open(validating_file, mode='rb') as f:
    valid = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)

X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

print("Number of training examples =", X_train.shape[0])
print("Number of validating examples =", X_valid.shape[0])
print("Number of testing examples =", X_test.shape[0])
print("Image data shape =", X_train[0].shape)
print("Number of classes =", len(np.unique(y_train)))

batch_size = 128
epochs = 30
model = conv_model()

adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.01)

model.compile(loss='sparse_categorical_crossentropy',
              optimizer=adam,
              metrics=['accuracy'])

checkpointer = ModelCheckpoint(filepath="./output/stn.h5", verbose=1, save_best_only=True, save_weights_only=True)

model.summary()
# Out:
# Using TensorFlow backend.
# Number of training examples = 34799
# Number of validating examples = 4410
# Number of testing examples = 12630
# Image data shape = (32, 32, 3)
# Number of classes = 43
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda_1 (Lambda)            (None, 32, 32, 3)         0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 3)         12
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 10)        40
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 32, 32, 10)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 10)        40
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 3)         33
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 32, 32, 3)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32, 32, 3)         12
# _________________________________________________________________
# spatial_transformer_1 (Spati (None, 32, 32, 3)         50662
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 16)        1216
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 32, 32, 16)        64
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 32, 32, 32)        12832
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 32, 32, 64)        51264
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 32, 32, 96)        153696
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 32, 32, 96)        384
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 32, 32, 128)       307328
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 32, 32, 192)       614592
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 32, 32, 192)       768
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 16, 192)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 16, 16, 256)       1229056
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 16, 16, 256)       1024
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 8, 8, 128)         819328
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 8, 8, 64)          204864
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 1, 1, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 43)                2795
# =================================================================
# Total params: 3,451,418
# Trainable params: 3,449,562
# Non-trainable params: 1,856
# _________________________________________________________________

# %% [markdown]
# ## Training

# %%
try:
    history = model.fit(X_train, y_train,
                batch_size=batch_size,
                epochs=epochs,
                validation_data=(X_valid, y_valid),
                shuffle=True,
                callbacks=[checkpointer])
except KeyboardInterrupt:
    print("training interrupted")
# Out:
# Train on 34799 samples, validate on 4410 samples
# Epoch 1/30
# 34799/34799 [==============================] - 68s 2ms/step - loss: 13.1705 - acc: 0.2852 - val_loss: 5.7464 - val_acc: 0.3342
#
# Epoch 00001: val_loss improved from inf to 5.74643, saving model to ./output/stn.h5
# Epoch 2/30
# 34799/34799 [==============================] - 61s 2ms/step - loss: 2.3979 - acc: 0.8702 - val_loss: 4.5823 - val_acc: 0.7796
#
# Epoch 00002: val_loss improved from 5.74643 to 4.58231, saving model to ./output/stn.h5
# Epoch 3/30
# 34799/34799 [==============================] - 60s 2ms/step - loss: 1.4450 - acc: 0.9651 - val_loss: 1.8182 - val_acc: 0.9803
#
# Epoch 00003: val_loss improved from 4.58231 to 1.81819, saving model to ./output/stn.h5
# Epoch 4/30
# 34799/34799 [==============================] - 61s 2ms/step - loss: 1.1384 - acc: 0.9778 - val_loss: 1.0335 - val_acc: 0.9889
#
# Epoch 00004: val_loss improved from 1.81819 to 1.03354, saving model to ./output/stn.h5
# Epoch 5/30
# 34799/34799 [==============================] - 61s 2ms/step - loss: 0.9796 - acc: 0.9813 - val_loss: 0.9222 - val_acc: 0.9837
#
# Epoch 00005: val_loss improved from 1.03354 to 0.92224, saving model to ./output/stn.h5
# Epoch 6/30
# 34799/34799 [==============================] - 61s 2ms/step - loss: 0.8925 - acc: 0.9833 - val_loss: 1.0532 - val_acc: 0.9637
#
# Epoch 00006: val_loss did not improve from 0.92224
# Epoch 7/30
# 34799/34799 [==============================] - 61s 2ms/step - loss: 0.8262 - acc: 0.9857 - val_loss: 0.8313 - val_acc: 0.9825
#
# Epoch 00007: val_loss improved from 0.92224 to 0.83134, saving model to ./output/stn.h5
# Epoch 8/30
# 34799/34799 [==============================] - 61s 2ms/step - loss: 0.7554 - acc: 0.9866 - val_loss: 0.7236 - val_acc: 0.9878
#
# Epoch 00008: val_loss improved from 0.83134 to 0.72361, saving model to ./output/stn.h5
# Epoch 9/30
# 34799/34799 [==============================] - 61s 2ms/step - loss: 0.7045 - acc: 0.9884 - val_loss: 0.6759 - val_acc: 0.9889
#
# Epoch 00009: val_loss improved from 0.72361 to 0.67593, saving model to ./output/stn.h5
# Epoch 10/30
# 34799/34799 [==============================] - 61s 2ms/step - loss: 0.6668 - acc: 0.9891 - val_loss: 0.6510 - val_acc: 0.9862
#
# Epoch 00010: val_loss improved from 0.67593 to 0.65101, saving model to ./output/stn.h5
# Epoch 11/30
# 34799/34799 [==============================] - 61s 2ms/step - loss: 0.6385 - acc: 0.9893 - val_loss: 0.5933 - val_acc: 0.9961
#
# Epoch 00011: val_loss improved from 0.65101 to 0.59334, saving model to ./output/stn.h5
# Epoch 12/30
# 34799/34799 [==============================] - 61s 2ms/step - loss: 0.6100 - acc: 0.9903 - val_loss: 0.5770 - val_acc: 0.9900
#
# Epoch 00012: val_loss improved from 0.59334 to 0.57701, saving model to ./output/stn.h5
# Epoch 13/30
# 34799/34799 [==============================] - 61s 2ms/step - loss: 0.5865 - acc: 0.9904 - val_loss: 0.5521 - val_acc: 0.9907
#
# Epoch 00013: val_loss improved from 0.57701 to 0.55214, saving model to ./output/stn.h5
# Epoch 14/30
# 34799/34799 [==============================] - 61s 2ms/step - loss: 0.5679 - acc: 0.9895 - val_loss: 0.5472 - val_acc: 0.9871
#
# Epoch 00014: val_loss improved from 0.55214 to 0.54719, saving model to ./output/stn.h5
# Epoch 15/30
# 34799/34799 [==============================] - 61s 2ms/step - loss: 0.5500 - acc: 0.9907 - val_loss: 0.5108 - val_acc: 0.9941
#
# Epoch 00015: val_loss improved from 0.54719 to 0.51084, saving model to ./output/stn.h5
# Epoch 16/30
# 34799/34799 [==============================] - 61s 2ms/step - loss: 0.5242 - acc: 0.9903 - val_loss: 0.4832 - val_acc: 0.9968
#
# Epoch 00016: val_loss improved from 0.51084 to 0.48317, saving model to ./output/stn.h5
# Epoch 17/30
# 34799/34799 [==============================] - 61s 2ms/step - loss: 0.5079 - acc: 0.9909 - val_loss: 0.4974 - val_acc: 0.9893
#
# Epoch 00017: val_loss did not improve from 0.48317
# Epoch 18/30
# 34799/34799 [==============================] - 61s 2ms/step - loss: 0.4931 - acc: 0.9917 - val_loss: 0.4659 - val_acc: 0.9943
#
# Epoch 00018: val_loss improved from 0.48317 to 0.46592, saving model to ./output/stn.h5
# Epoch 19/30
# 34799/34799 [==============================] - 61s 2ms/step - loss: 0.4805 - acc: 0.9911 - val_loss: 0.4436 - val_acc: 0.9955
#
# Epoch 00019: val_loss improved from 0.46592 to 0.44359, saving model to ./output/stn.h5
# Epoch 20/30
# 34799/34799 [==============================] - 61s 2ms/step - loss: 0.4636 - acc: 0.9925 - val_loss: 0.4473 - val_acc: 0.9934
#
# Epoch 00020: val_loss did not improve from 0.44359
# Epoch 21/30
# 34799/34799 [==============================] - 62s 2ms/step - loss: 0.4584 - acc: 0.9915 - val_loss: 0.4366 - val_acc: 0.9914
#
# Epoch 00021: val_loss improved from 0.44359 to 0.43661, saving model to ./output/stn.h5
# Epoch 22/30
# 34799/34799 [==============================] - 61s 2ms/step - loss: 0.4414 - acc: 0.9923 - val_loss: 0.4217 - val_acc: 0.9964
#
# Epoch 00022: val_loss improved from 0.43661 to 0.42169, saving model to ./output/stn.h5
# Epoch 23/30
# 34799/34799 [==============================] - 62s 2ms/step - loss: 0.4311 - acc: 0.9921 - val_loss: 0.3944 - val_acc: 0.9966
#
# Epoch 00023: val_loss improved from 0.42169 to 0.39436, saving model to ./output/stn.h5
# Epoch 24/30
# 34799/34799 [==============================] - 61s 2ms/step - loss: 0.4176 - acc: 0.9930 - val_loss: 0.3865 - val_acc: 0.9964
#
# Epoch 00024: val_loss improved from 0.39436 to 0.38648, saving model to ./output/stn.h5
# Epoch 25/30
# 34799/34799 [==============================] - 61s 2ms/step - loss: 0.4095 - acc: 0.9922 - val_loss: 0.3898 - val_acc: 0.9943
#
# Epoch 00025: val_loss did not improve from 0.38648
# Epoch 26/30
# 34799/34799 [==============================] - 62s 2ms/step - loss: 0.3991 - acc: 0.9930 - val_loss: 0.3712 - val_acc: 0.9959
#
# Epoch 00026: val_loss improved from 0.38648 to 0.37122, saving model to ./output/stn.h5
# Epoch 27/30
# 34799/34799 [==============================] - 62s 2ms/step - loss: 0.3949 - acc: 0.9924 - val_loss: 0.3892 - val_acc: 0.9884
#
# Epoch 00027: val_loss did not improve from 0.37122
# Epoch 28/30
# 34799/34799 [==============================] - 62s 2ms/step - loss: 0.3896 - acc: 0.9924 - val_loss: 0.3811 - val_acc: 0.9893
#
# Epoch 00028: val_loss did not improve from 0.37122
# Epoch 29/30
# 34799/34799 [==============================] - 61s 2ms/step - loss: 0.3800 - acc: 0.9928 - val_loss: 0.3603 - val_acc: 0.9959
#
# Epoch 00029: val_loss improved from 0.37122 to 0.36028, saving model to ./output/stn.h5
# Epoch 30/30
# 34799/34799 [==============================] - 62s 2ms/step - loss: 0.3693 - acc: 0.9930 - val_loss: 0.3620 - val_acc: 0.9914
#
# Epoch 00030: val_loss did not improve from 0.36028

# %%
import matplotlib.pyplot as plt

def plot_train_history(history, train_metrics, val_metrics):
    plt.plot(history.history.get(train_metrics),'b-*')
    plt.plot(history.history.get(val_metrics),'r-*')
    plt.ylabel(train_metrics)
    plt.xlabel('Epochs')
    plt.legend(['train', 'validation'])
    
    
plt.figure(figsize=(12,4))
plt.grid()
plt.subplot(1,2,1)
plot_train_history(history, 'loss','val_loss')


plt.subplot(1,2,2)
plot_train_history(history, 'acc','val_acc')


plt.show()

# %% [markdown]
# ## Evaluation

# %%
model.load_weights("./output/stn.h5")
y_pred = model.predict_classes(X_test)
acc = np.sum(y_pred==y_test)/np.size(y_pred)
print("Test accuracy = {}".format(acc))
# Out:
# Test accuracy = 0.9937450514647664
